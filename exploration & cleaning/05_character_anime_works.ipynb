# %% [markdown]
# # 05 – Character Anime Works
#
# Esplorazione e data cleaning del dataset `character_anime_works.csv`.
#
# **Colonne:**
# | Colonna | Descrizione |
# |---|---|
# | `anime_mal_id` | ID univoco dell'anime su MyAnimeList |
# | `character_mal_id` | ID univoco del personaggio su MyAnimeList |
# | `character_name` | Nome del personaggio |
# | `role` | Ruolo del personaggio nell'anime |

# %% [markdown]
# ## 1. Import e caricamento dati
# Importiamo le librerie necessarie e carichiamo il file csv. Facciamo una esplorazione generica per capire la struttura e le caratteristiche del dataset.

# %%
import pandas as pd
import numpy as np
from dataset_analyzer import analyze
from foreign_key_analyzer import check_fk

df_works = pd.read_csv('../datasets/character_anime_works.csv')
print(f'Shape: {df_works.shape}')
print()
df_works.info()
print()
df_works.head()
# Out:
# Shape: (236816, 4)
#
# <class 'pandas.DataFrame'>
# RangeIndex: 236816 entries, 0 to 236815
# Data columns (total 4 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   anime_mal_id      236816 non-null  int64
#  1   character_mal_id  236816 non-null  int64
#  2   character_name    236816 non-null  str
#  3   role              236816 non-null  str
# dtypes: int64(2), str(2)
# memory usage: 7.2 MB
#    anime_mal_id  character_mal_id character_name        role
# 0          2928              5781          Atoli        Main
# 1          2928                33          Haseo        Main
# 2          2928                32           Ovan        Main
# 3          2928                34          Shino        Main
# 4          2928              5785           Aina  Supporting

# %% [markdown]
# Il dataset contiene **236.816 righe** e **4 colonne**. Tutte le colonne sono complete: **nessun valore nullo** in nessuna delle 4 colonne. I tipi di dati sono adeguati: `int64` per gli ID e `str` per le colonne testuali.

# %% [markdown]
# ## 1.1 Rimozione duplicati esatti
#
# Prima dell'analisi per colonna, rimuoviamo le righe con valori identici in **tutte** le colonne, mantenendo solo la prima occorrenza.

# %%
n_originale = len(df_works)

mask_dup = df_works.duplicated(keep=False)       # tutte le occorrenze coinvolte
n_righe_coinvolte = mask_dup.sum()                    # righe totali che hanno almeno un duplicato
n_gruppi = df_works[mask_dup].duplicated(keep='first').sum()  # occorrenze extra (da rimuovere)
n_tenute = n_righe_coinvolte - n_gruppi               # prime occorrenze mantenute

print(f'Righe totali coinvolte in duplicazioni : {n_righe_coinvolte:,}')
print(f'  → prime occorrenze mantenute         : {n_tenute:,}')
print(f'  → occorrenze extra rimosse           : {n_gruppi:,}')
print()

df_works.drop_duplicates(keep='first', inplace=True)
print(f'Righe prima della rimozione : {n_originale:,}')
print(f'Righe dopo la rimozione     : {len(df_works):,}')
# Out:
# Righe totali coinvolte in duplicazioni : 0
#   → prime occorrenze mantenute         : 0
#   → occorrenze extra rimosse           : 0
#
# Righe prima della rimozione : 236,816
# Righe dopo la rimozione     : 236,816

# %% [markdown]
# Nessun duplicato esatto trovato. Tutte le 236.816 righe sono già uniche. Il dataset rimane invariato.
#
# Adesso che siamo sicuri che tutte le righe sono uniche, iniziamo l'analisi per colonne utilizzando la nostra libreria `dataset_analyzer`.

# %% [markdown]
# ## 2. Analisi colonna per colonna

# %% [markdown]
# ### 2.1 `anime_mal_id`
#
# Questa colonna è una **chiave esterna** che referenzia la chiave primaria `mal_id` di `details.csv`.
#
# I valori duplicati sono **attesi**: ogni anime è associato a più personaggi.
#
# I controlli rilevanti sono:
# - **Valori nulli**: una chiave esterna nulla indica una riga senza riferimento che va rimossa.
# - **Integrità referenziale**: ogni ID presente qui deve esistere in `details_clean.csv`.
#
# Usiamo `check_fk` per entrambi i controlli.

# %%
df_details = pd.read_csv('../datasets_cleaned/details_clean.csv')

mask_orphan_anime = check_fk(df_works['anime_mal_id'], df_details['mal_id'], child_df=df_works)

print(f'Null in anime_mal_id            : {df_works["anime_mal_id"].isna().sum()}')
print(f'Duplicati in anime_mal_id (attesi): {df_works["anime_mal_id"].duplicated().sum():,}')
# Out:
#   Colonna FK  (tabella figlia)        anime_mal_id
#   Colonna PK  (tabella padre)         mal_id
# ────────────────────────────────────────────────────────────────────────────────
#
# Riepilogo conteggi
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali (tabella figlia)       236,816
#   Valori null nella FK                0  (0.00%)
#   Valori non-null nella FK            236,816  (100.00%)
#   Valori unici nella PK padre         28,955
#
#   ✓  Righe con FK valida              236,816  (100.00%)
#   ✗  Righe orfane (FK non in PK)      0  (0.00%)
#      → ID orfani unici                0
#
# Valutazione integrità referenziale
# ────────────────────────────────────────────────────────────────────────────────
#
# Nessuna violazione. Tutti i valori FK esistono nella tabella padre.
#
# Null in anime_mal_id            : 0
# Duplicati in anime_mal_id (attesi): 221,532

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i 236.816 record hanno un ID anime valido.
# - **Integrità referenziale**: nessuna riga orfana. Tutti i 15.284 ID anime presenti in questo dataset esistono in `details_clean.csv`.
# - **Duplicati attesi**: ogni anime è associato a più personaggi.
#
# Nessuna pulizia è necessaria.

# %% [markdown]
# ### 2.2 `character_mal_id`
#
# Questa colonna è una **chiave esterna** che referenzia la chiave primaria di `characters.csv`. Per una chiave esterna le statistiche descrittive non hanno significato interpretativo.
#
# I controlli rilevanti sono:
# - **Valori nulli**: una chiave esterna nulla indica una riga senza riferimento che va rimossa.
# - **Integrità referenziale**: ogni ID presente qui deve esistere in `characters_clean.csv`.
#
# Usiamo quindi `check_fk` al posto di `analyze`, che effettua entrambi i controlli.
#
# I valori duplicati sono **attesi**: lo stesso personaggio può apparire in più anime (es. crossover, sequel).

# %%
df_characters = pd.read_csv('../datasets_cleaned/characters_clean.csv')

mask_orphan = check_fk(
    df_works['character_mal_id'],
    df_characters['character_mal_id'],
    child_df=df_works
)

print(f'Null in character_mal_id  : {df_works["character_mal_id"].isna().sum()}')
print(f'Duplicati in character_mal_id (attesi) : {df_works["character_mal_id"].duplicated().sum():,}')
# Out:
#   Colonna FK  (tabella figlia)        character_mal_id
#   Colonna PK  (tabella padre)         character_mal_id
# ────────────────────────────────────────────────────────────────────────────────
#
# Riepilogo conteggi
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali (tabella figlia)       236,816
#   Valori null nella FK                0  (0.00%)
#   Valori non-null nella FK            236,816  (100.00%)
#   Valori unici nella PK padre         209,506
#
#   ✓  Righe con FK valida              236,814  (100.00%)
#   ✗  Righe orfane (FK non in PK)      2  (0.00%)
#      → ID orfani unici                2
#
# Valutazione integrità referenziale
# ────────────────────────────────────────────────────────────────────────────────
#
# 2 riga/e (0.00%) violano l'integrità referenziale.
#
# Campione righe orfane (prime 2)
# ────────────────────────────────────────────────────────────────────────────────
#
#         anime_mal_id  character_mal_id      character_name        role
# 211840          3009            281878  The Egyptian Mummy  Supporting
# 211843          3009            281879        The Lion Man  Supporting
#
# Null in character_mal_id  : 0
# Duplicati in character_mal_id (attesi) : 91,598

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i 236.816 record hanno un ID personaggio di riferimento.
# - **Integrità referenziale**: 2 righe orfane rilevate (`character_mal_id` 281878 e 281879, entrambe relative all'anime 3009). I corrispondenti personaggi non sono presenti in `characters_clean.csv`. Le righe vanno rimosse.

# %%
if mask_orphan.any():
    n_orfane = mask_orphan.sum()
    df_works = df_works[~mask_orphan].reset_index(drop=True)
    print(f'Righe orfane rimosse : {n_orfane}')
    print(f'Righe rimanenti      : {len(df_works):,}')
else:
    print('Nessuna riga orfana da rimuovere.')
# Out:
# Righe orfane rimosse : 2
# Righe rimanenti      : 236,814

# %% [markdown]
# ### 2.3 `character_name`
#
# Colonna che contiene il nome del personaggio. Ci interessa verificare la presenza di valori nulli, duplicati e caratteri anomali. Per questo utilizziamo `analyze`.
#
# I duplicati sono **attesi** in quanto personaggi diversi possono condividere lo stesso nome e lo stesso personaggio appare in più righe (una per ogni anime in cui compare).

# %%
df_works['character_name'] = df_works['character_name'].str.strip()
analyze(df_works['character_name'])
# Out:
#   Nome serie                     character_name
#   dtype                          str
#   Dimensione                     236,814
#   Range indice                   0 … 236813
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   236,814
#   Valori non nulli               236,814  (100.00%)
#   Null / NaN                     0  (0.00%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   114,583  (48.39%)
#   Valori duplicati               122,231  (51.61%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  1  caratteri
#   Lunghezza max                  55  caratteri
#   Lunghezza media                11.23  caratteri
#   Lunghezza mediana              12.0000  caratteri
#   Dev. standard lunghezza        4.90
#   IQR lunghezza                  8.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ───────────────────────────────────────────────────
#    #1          55   de La Vallière, Éléonore Albertine Le Blanc de La …
#    #2          55   de La Vallière, Éléonore Albertine Le Blanc de La …
#    #3          55   de La Vallière, Éléonore Albertine Le Blanc de La …
#    #4          51   Atosryua Syun-Atos Febdash Lyuf Raika Febdac, Srum…
#    #5          51   Atosryua Syun-Atos Febdash Lyuf Raika Febdac, Srum…
#    #6          51   Kirara Rodriguez Matured XVIII Evening Star SS Plu…
#    #7          51   Kirara Rodriguez Matured XVIII Evening Star SS Plu…
#    #8          50   von Braunschbank-Albrechtsberger, Constanze Amalie
#    #9          50   von Braunschbank-Albrechtsberger, Constanze Amalie
#   #10          50   Kim Nicholas Fidel Muammar Tikriti Adolf de Komach
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ──────
#    #1           1   E
#    #2           1   K
#    #3           1   W
#    #4           1   W
#    #5           1   W
#    #6           1   W
#    #7           1   E
#    #8           1   J
#    #9           1   R
#   #10           1   J
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   1 – 3                               5,018     2.1%
#   3 – 6                              51,904    21.9%
#   6 – 9                              35,080    14.8%
#   9 – 11                             19,989     8.4%
#   11 – 14                            58,856    24.9%
#   14 – 17                            48,940    20.7%
#   17 – 19                             9,867     4.2%
#   19 – 22                             4,483     1.9%
#   22 – 25                             1,454     0.6%
#   25 – 28                               440     0.2%
#   28 – 30                               364     0.2%
#   30 – 33                               180     0.1%
#   33 – 36                                99     0.0%
#   36 – 38                                44     0.0%
#   38 – 41                                42     0.0%
#   41 – 44                                19     0.0%
#   44 – 46                                15     0.0%
#   46 – 49                                 9     0.0%
#   49 – 52                                 8     0.0%
#   52 – 55                                 3     0.0%
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore      Conteggio      %
#   ─────────   ─────────   ────
#   Narrator        1,042   0.4%
#   Pikachu           152   0.1%
#   Principal         100   0.0%
#   Nyarth             96   0.0%
#   Maria              94   0.0%
#   Satoshi            93   0.0%
#   Doctor             89   0.0%
#   Yuki               86   0.0%
#   King               86   0.0%
#   Musashi            85   0.0%
#
#   I 10 meno frequenti (più rari):
#   Valore                Conteggio      %
#   ───────────────────   ─────────   ────
#   Shiraha, Setsuna              1   0.0%
#   Tunika                        1   0.0%
#   Shaderan, Anastasia           1   0.0%
#   Shaderan, Gregor              1   0.0%
#   Shaderan, Cedric              1   0.0%
#   Shaderan, Sasha               1   0.0%
#   Shaderan, Elvira              1   0.0%
#   Ruifon                        1   0.0%
#   Ilza                          1   0.0%
#   Granado, Liu Liu              1   0.0%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 1,000  (0.4%)
#   Contiene maiuscole             236,757  (100.0%)
#   Contiene minuscole             236,242  (99.8%)
#   Contiene spazi                 144,311  (60.9%)
#   Contiene caratteri speciali    134,622  (56.8%)
#   Contiene URL                   0  (0.0%)
#   Contiene @                     13  (0.0%)
#   Solo numerico                  21
#   Solo alfabetico                88,137
#   Solo alfanumerico              88,265
#
# Analisi parole / token
# ────────────────────────────────────────────────────────────────────────────────
#
#   Parole medie per valore        1.66
#   Max parole                     10
#   Min parole                     1
#
#   Le 10 parole più comuni:
#   Parola                  Conteggio
#   ────────────────────   ──────────
#   Mother                      1,747
#   Father                      1,235
#   Narrator                    1,049
#   no                            654
#   von                           567
#   Akira                         567
#   of                            533
#   Tachibana,                    523
#   Dr.                           490
#   Makoto                        470

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i record hanno un nome personaggio.
# - **Duplicati attesi**: personaggi diversi possono condividere lo stesso nome e lo stesso personaggio appare più volte.
# - Ci sono 13 nomi contenenti il carattere `@` e 21 nomi solo numerici. Li stampiamo per verificare se si tratta di errori.
# - Stampiamo anche i nomi più lunghi e più corti per un' ulteriore verifica.

# %%
lunghezze = df_works['character_name'].str.len()

top10_lunghi = df_works.loc[lunghezze.nlargest(10).index].assign(caratteri=lunghezze)
top10_corti  = df_works.loc[lunghezze.nsmallest(10).index].assign(caratteri=lunghezze)

print("10 nomi più lunghi:")
print(top10_lunghi.to_string(index=False))
print()
print("10 nomi più corti:")
print(top10_corti.to_string(index=False))
print()

# Nomi contenenti '@'
cn_con_at = df_works[df_works['character_name'].str.contains('@', regex=False)]
print(f"character_name contenenti '@': {len(cn_con_at)}")
print(cn_con_at.to_string(index=False))
print()

# Nomi solo numerici
cn_numerici = df_works[df_works['character_name'].str.fullmatch(r'\d+')]
print(f"character_name solo numerici: {len(cn_numerici)}")
print(cn_numerici.to_string(index=False))
# Out:
# 10 nomi più lunghi:
#  anime_mal_id  character_mal_id                                          character_name       role  caratteri
#         11319              8813 de La Vallière, Éléonore Albertine Le Blanc de La Blois Supporting         55
#          1840              8813 de La Vallière, Éléonore Albertine Le Blanc de La Blois Supporting         55
#          3712              8813 de La Vallière, Éléonore Albertine Le Blanc de La Blois Supporting         55
#           290            130250     Atosryua Syun-Atos Febdash Lyuf Raika Febdac, Srumh Supporting         51
#          1381            130250     Atosryua Syun-Atos Febdash Lyuf Raika Febdac, Srumh Supporting         51
#         43299            223757     Kirara Rodriguez Matured XVIII Evening Star SS Plum Supporting         51
#         48614            223757     Kirara Rodriguez Matured XVIII Evening Star SS Plum Supporting         51
#         33489            130849      von Braunschbank-Albrechtsberger, Constanze Amalie Supporting         50
#         19489            130849      von Braunschbank-Albrechtsberger, Constanze Amalie Supporting         50
#           615             27288      Kim Nicholas Fidel Muammar Tikriti Adolf de Komach Supporting         50
#
# 10 nomi più corti:
#  anime_mal_id  character_mal_id character_name       role  caratteri
#          5053             35275              E Supporting          1
#          7193             28385              K       Main          1
#         42163            198347              W Supporting          1
#         53881            198347              W Supporting          1
#         50205            198347              W Supporting          1
#         58749            198347              W Supporting          1
#         39622            170942              E Supporting          1
#          2705             37036              J Supporting          1
#          2705            187981              R Supporting          1
#          2706             37036              J Supporting          1
#
# character_name contenenti '@': 13
#  anime_mal_id  character_mal_id                           character_name       role
#         23321            134304                           Nantakei@Akiba Supporting
#         48981            228277                                     @Gou Supporting
#          2261            145607                                Joe@Admin       Main
#          2261             19936                              Malice@Doll       Main
#          2261            145660                              Amanda@Doll Supporting
#          2261            145659                           Devo@Leukocyte Supporting
#          2261            145663                               Doris@Doll Supporting
#          2261            145662                                Elza@Doll Supporting
#          2261             94991                            Freddy@Licker Supporting
#          2261            145661                             Heather@Doll Supporting
#          2261            268374                               Misty@Doll Supporting
#         57947            279716                            Mio@ItanGirls Supporting
#          9863             67265 Yunyun Bloody Star (Kai)@Suzuki Bakugeki Supporting
#
# character_name solo numerici: 21
#  anime_mal_id  character_mal_id character_name       role
#         35849            158054            081 Supporting
#         35849            159113            090 Supporting
#         35849            161165            245 Supporting
#           974              9202            666 Supporting
#           974              9203            777 Supporting
#           277            255921            369 Supporting
#         35240            152288              7 Supporting
#         37807            152288              7 Supporting
#         41140            152288              7 Supporting
#         41141            152288              7 Supporting
#         57093            152288              7 Supporting
#         16694             43302             18 Supporting
#          3806            215518         004989 Supporting
#          3806            215517          00893 Supporting
#         42307            271698            777 Supporting
#          3317            264061             01 Supporting
#          3317            264062             07 Supporting
#          4264             11592            044       Main
#          4264             74499            724 Supporting
#           553             17574            003 Supporting
#         53919            279700          81199       Main

# %% [markdown]
# - **Nomi contenenti `@`**: 13 valori, coerenti con quanto già analizzato in `characters_clean.csv`. Il simbolo `@` è un separatore ufficiale MAL (es. `Doris@Doll`). Nessuna pulizia necessaria.
# - **Nomi solo numerici**: 21 valori, anch'essi coerenti con `characters_clean.csv`. Sono designazioni numeriche ufficiali di personaggi (es. cloni, androidi). Nessuna pulizia necessaria.
# - Dalla verifica dei nomi più corti e più lunghi non emerge nessuna anomalia. Nessuna pulizia necessaria.

# %% [markdown]
# ### 2.4 `role`
#
# Colonna che indica il ruolo del personaggio nell'anime. Utilizziamo `analyze` per verificare che non ci siano valori nulli o anomalie.

# %%
df_works['role'] = df_works['role'].str.strip()
analyze(df_works['role'])
# Out:
#   Nome serie                     role
#   dtype                          str
#   Dimensione                     236,814
#   Range indice                   0 … 236813
#   Tipo                           STRINGA / OGGETTO
#
# Conteggi di base
# ────────────────────────────────────────────────────────────────────────────────
#
#   Righe totali                   236,814
#   Valori non nulli               236,814  (100.00%)
#   Null / NaN                     0  (0.00%)
#     di cui stringhe vuote        0  (convertite a NULL)
#   Valori unici                   2  (0.00%)
#   Valori duplicati               236,812  (100.00%)
#
# Analisi lunghezza stringhe
# ────────────────────────────────────────────────────────────────────────────────
#
#   Lunghezza min                  4  caratteri
#   Lunghezza max                  10  caratteri
#   Lunghezza media                8.72  caratteri
#   Lunghezza mediana              10.0000  caratteri
#   Dev. standard lunghezza        2.46
#   IQR lunghezza                  0.0000
#
# Valori di lunghezza estrema
# ────────────────────────────────────────────────────────────────────────────────
#
#   Le 10 stringhe più lunghe:
#     #   Lunghezza   Valore
#   ───   ─────────   ──────────
#    #1          10   Supporting
#    #2          10   Supporting
#    #3          10   Supporting
#    #4          10   Supporting
#    #5          10   Supporting
#    #6          10   Supporting
#    #7          10   Supporting
#    #8          10   Supporting
#    #9          10   Supporting
#   #10          10   Supporting
#
#   Le 10 stringhe più corte:
#     #   Lunghezza   Valore
#   ───   ─────────   ──────
#    #1           4   Main
#    #2           4   Main
#    #3           4   Main
#    #4           4   Main
#    #5           4   Main
#    #6           4   Main
#    #7           4   Main
#    #8           4   Main
#    #9           4   Main
#   #10           4   Main
#
# Distribuzione lunghezze
# ────────────────────────────────────────────────────────────────────────────────
#
#   Intervallo                      Conteggio        %
#   ────────────────────────────── ──────────   ──────
#   4 – 4                              50,531    21.3%
#   4 – 5                                   0     0.0%
#   5 – 6                                   0     0.0%
#   6 – 7                                   0     0.0%
#   7 – 8                                   0     0.0%
#   8 – 9                                   0     0.0%
#   9 – 10                            186,283    78.7%
#
# Valori più e meno frequenti
# ────────────────────────────────────────────────────────────────────────────────
#
#   I 10 più frequenti:
#   Valore       Conteggio       %
#   ──────────   ─────────   ─────
#   Supporting     186,283   78.7%
#   Main            50,531   21.3%
#
#   I 10 meno frequenti (più rari):
#   Valore       Conteggio       %
#   ──────────   ─────────   ─────
#   Main            50,531   21.3%
#   Supporting     186,283   78.7%
#
# Analisi pattern / contenuto
# ────────────────────────────────────────────────────────────────────────────────
#
#   Contiene cifre                 0  (0.0%)
#   Contiene maiuscole             236,814  (100.0%)
#   Contiene minuscole             236,814  (100.0%)
#   Contiene spazi                 0  (0.0%)
#   Contiene caratteri speciali    0  (0.0%)
#   Contiene URL                   0  (0.0%)
#   Contiene @                     0  (0.0%)
#   Solo numerico                  0
#   Solo alfabetico                236,814
#   Solo alfanumerico              236,814

# %% [markdown]
# **Osservazioni:**
# - **Nessun valore nullo**: tutti i 236.816 record hanno un ruolo definito.
# - **Solo 2 valori distinti**: `Main` e `Supporting`.
# - La distribuzione (~78.6% `Supporting`, ~21.4% `Main`) è coerente in quanto i personaggi principali sono sempre una minoranza in confronto ai personaggi di supporto.
#
# Nessuna pulizia è necessaria.

# %% [markdown]
# ### 2.5 Chiave primaria `(anime_mal_id, character_mal_id)`
#
# Questa tabella è una relazione molti-a-molti tra anime e personaggi. La chiave primaria è la coppia `(anime_mal_id, character_mal_id)`. Verifichiamo che sia univoca.

# %%
n_pk_dup = df_works.duplicated(subset=['anime_mal_id', 'character_mal_id'], keep=False).sum()
print(f'Duplicati su (anime_mal_id, character_mal_id): {n_pk_dup}')

if n_pk_dup > 0:
    print('→ Rimozione duplicati sulla chiave primaria...')
    df_works.drop_duplicates(subset=['anime_mal_id', 'character_mal_id'], keep='first', inplace=True)
    print(f'Righe dopo la rimozione: {len(df_works):,}')
else:
    print('→ Chiave primaria già univoca, nessuna operazione richiesta.')
# Out:
# Duplicati su (anime_mal_id, character_mal_id): 0
# → Chiave primaria già univoca, nessuna operazione richiesta.

# %% [markdown]
# **Osservazioni:**
# La coppia `(anime_mal_id, character_mal_id)` è **univoca** per tutte le righe. La struttura della tabella è corretta.

# %% [markdown]
# ## 3. Riepilogo e Salvataggio
# Le operazioni di pulizia sono state effettuate colonna per colonna nella sezione 2. In questa sezione riepiloghiamo il risultato ed effettuiamo il salvataggio del dataset finale.

# %%
print('Riepilogo Dataset Pulito')
print(f'Righe originali      : {n_originale:>10,}')
print(f'Righe dopo cleaning  : {len(df_works):>10,}')
print(f'Righe rimosse totali : {n_originale - len(df_works):>10,}')
print()

df_works.to_csv('../datasets_cleaned/character_anime_works_clean.csv', index=False)
print('Salvato: datasets_cleaned/character_anime_works_clean.csv')
# Out:
# Riepilogo Dataset Pulito
# Righe originali      :    236,816
# Righe dopo cleaning  :    236,814
# Righe rimosse totali :          2
#
# Salvato: datasets_cleaned/character_anime_works_clean.csv
